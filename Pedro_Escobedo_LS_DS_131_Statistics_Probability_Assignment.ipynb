# %% [markdown]
# <a href="https://colab.research.google.com/github/pedroescobedob/DS-Unit-1-Sprint-3-Statistical-Tests-and-Experiments/blob/master/Pedro_Escobedo_LS_DS_131_Statistics_Probability_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img align="left" src="https://lever-client-logos.s3.amazonaws.com/864372b1-534c-480e-acd5-9711f850815c-1524247202159.png" width=200>
# <br></br>
# <br></br>
#
# ## *Data Science Unit 1 Sprint 3 Assignment 1*
#
# # Apply the t-test to real data
#
# Your assignment is to determine which issues have "statistically significant" differences between political parties in this [1980s congressional voting data](https://archive.ics.uci.edu/ml/datasets/Congressional+Voting+Records). The data consists of 435 instances (one for each congressperson), a class (democrat or republican), and 16 binary attributes (yes or no for voting for or against certain issues). Be aware - there are missing values!
#
# Your goals:
#
# 1. Load and clean the data (or determine the best method to drop observations when running tests)
# 2. Using hypothesis testing, find an issue that democrats support more than republicans with p < 0.01
# 3. Using hypothesis testing, find an issue that republicans support more than democrats with p < 0.01
# 4. Using hypothesis testing, find an issue where the difference between republicans and democrats has p > 0.1 (i.e. there may not be much of a difference)
#
# Note that this data will involve *2 sample* t-tests, because you're comparing averages across two groups (republicans and democrats) rather than a single group against a null hypothesis.
#
# Stretch goals:
#
# 1. Refactor your code into functions so it's easy to rerun with arbitrary variables
# 2. Apply hypothesis testing to your personal project data (for the purposes of this notebook you can type a summary of the hypothesis you formed and tested)

# %%
### YOUR CODE STARTS HERE

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import random
from matplotlib import style

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a14a5072-dd4a-426d-bbcb-1192635bc4bc" name="files[]" multiple disabled />
#      <output id="result-a14a5072-dd4a-426d-bbcb-1192635bc4bc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving house-votes-84.data to house-votes-84 (3).data

# %%
columns = ['Democrat or Republican',
           'Handicapped infants', 'Water project','Adoption of the budget resolution',
           'Physician fee','El Salvador Aid','Religious groups in schools',
           'Anti satellite test ban', 'Aid to Nicaraguan contras','Mx missile',
           'Immigration','Synfuels corporation cutback','Education spending',
           'Superfund right to sue','Crime','Duty free exports',
           'Export Administration Act South Africa']

# %%
house_votes = pd.read_csv('house-votes-84.data', names=columns)

# %%
house_votes.shape
# Out:
# (435, 17)

# %%
house_votes.head(10)
# Out:
#   Democrat or Republican  ... Export Administration Act South Africa
# 0             republican  ...                                      y
# 1             republican  ...                                      ?
# 2               democrat  ...                                      n
# 3               democrat  ...                                      y
# 4               democrat  ...                                      y
# 5               democrat  ...                                      y
# 6               democrat  ...                                      y
# 7             republican  ...                                      y
# 8             republican  ...                                      y
# 9               democrat  ...                                      ?
#
# [10 rows x 17 columns]

# %%
# defining what a missing values is

missing_values = ['?']

# %%
# Replacing the missing values with N/A values

df = pd.read_csv('house-votes-84.data', names=columns, na_values=missing_values)

# %%
df.head()
# Out:
#   Democrat or Republican  ... Export Administration Act South Africa
# 0             republican  ...                                      y
# 1             republican  ...                                    NaN
# 2               democrat  ...                                      n
# 3               democrat  ...                                      y
# 4               democrat  ...                                      y
#
# [5 rows x 17 columns]

# %%
df.shape
# Out:
# (435, 17)

# %%
# Total number of N/A values

print(df.isnull().sum().sum())
# Out:
# 392

# %%
# Converting strings into integers
y_or_n = {'y': 1,'n': 2}

# %%
new_df = df.replace(y_or_n)
new_df.head()
# Out:
#   Democrat or Republican  ...  Export Administration Act South Africa
# 0             republican  ...                                       1
# 1             republican  ...                                     nan
# 2               democrat  ...                                       2
# 3               democrat  ...                                       1
# 4               democrat  ...                                       1
#
# [5 rows x 17 columns]

# %%
new_df = pd.options.display.float_format = '{:,.0f}'.format

# %%
democrat = new_df[new_df['Democrat or Republican'] == 'democrat']

# %%
democrat.shape
# Out:
# (267, 17)

# %%
republican = new_df[new_df['Democrat or Republican'] == 'republican']

# %%
republican.shape
# Out:
# (168, 17)

# %%
democrat_1 = democrat.median()
democrat_1
# Out:
# Handicapped infants                      1
# Water project                            1
# Adoption of the budget resolution        1
# Physician fee                            2
# El Salvador Aid                          2
# Religious groups in schools              2
# Anti satellite test ban                  1
# Aid to Nicaraguan contras                1
# Mx missile                               1
# Immigration                              2
# Synfuels corporation cutback             1
# Education spending                       2
# Superfund right to sue                   2
# Crime                                    2
# Duty free exports                        1
# Export Administration Act South Africa   1
# dtype: float64

# %%
democrat.fillna(democrat_1, inplace=True)
democrat
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py:6130: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
#     Democrat or Republican  ...  Export Administration Act South Africa
# 2                 democrat  ...                                       2
# 3                 democrat  ...                                       1
# 4                 democrat  ...                                       1
# 5                 democrat  ...                                       1
# 6                 democrat  ...                                       1
# 9                 democrat  ...                                       1
# 12                democrat  ...                                       1
# 13                democrat  ...                                       1
# 16                democrat  ...                                       1
# 17                democrat  ...                                       1
# 19                democrat  ...                                       1
# 20                democrat  ...                                       1
# 21                democrat  ...                                       1
# 22                democrat  ...                                       1
# 23                democrat  ...                                       1
# 24                democrat  ...                                       1
# 25                democrat  ...                                       1
# 26                democrat  ...                                       1
# 27                democrat  ...                                       1
# 29                democrat  ...                                       1
# 31                democrat  ...                                       1
# 32                democrat  ...                                       1
# 34                democrat  ...                                       1
# 39                democrat  ...                                       1
# 40                democrat  ...                                       1
# 41                democrat  ...                                       1
# 42                democrat  ...                                       1
# 43                democrat  ...                                       1
# 44                democrat  ...                                       1
# 45                democrat  ...                                       1
# ..                     ...  ...                                     ...
# 385               democrat  ...                                       2
# 386               democrat  ...                                       1
# 387               democrat  ...                                       1
# 388               democrat  ...                                       1
# 389               democrat  ...                                       1
# 390               democrat  ...                                       1
# 391               democrat  ...                                       2
# 394               democrat  ...                                       1
# 395               democrat  ...                                       1
# 396               democrat  ...                                       1
# 397               democrat  ...                                       1
# 398               democrat  ...                                       1
# 406               democrat  ...                                       1
# 407               democrat  ...                                       2
# 408               democrat  ...                                       1
# 411               democrat  ...                                       1
# 414               democrat  ...                                       1
# 415               democrat  ...                                       1
# 417               democrat  ...                                       1
# 418               democrat  ...                                       1
# 419               democrat  ...                                       1
# 421               democrat  ...                                       1
# 422               democrat  ...                                       1
# 423               democrat  ...                                       1
# 424               democrat  ...                                       1
# 425               democrat  ...                                       1
# 426               democrat  ...                                       1
# 428               democrat  ...                                       1
# 429               democrat  ...                                       1
# 431               democrat  ...                                       1
#
# [267 rows x 17 columns]

# %%
republican_1 = republican.median()
republican_1
# Out:
# Handicapped infants                      2
# Water project                            1
# Adoption of the budget resolution        2
# Physician fee                            1
# El Salvador Aid                          1
# Religious groups in schools              1
# Anti satellite test ban                  2
# Aid to Nicaraguan contras                2
# Mx missile                               2
# Immigration                              1
# Synfuels corporation cutback             2
# Education spending                       1
# Superfund right to sue                   1
# Crime                                    1
# Duty free exports                        2
# Export Administration Act South Africa   1
# dtype: float64

# %%
republican.fillna(republican_1, inplace=True)
republican
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py:6130: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
#     Democrat or Republican  ...  Export Administration Act South Africa
# 0               republican  ...                                       1
# 1               republican  ...                                       1
# 7               republican  ...                                       1
# 8               republican  ...                                       1
# 10              republican  ...                                       2
# 11              republican  ...                                       1
# 14              republican  ...                                       1
# 15              republican  ...                                       1
# 18              republican  ...                                       2
# 28              republican  ...                                       1
# 30              republican  ...                                       2
# 33              republican  ...                                       1
# 35              republican  ...                                       2
# 36              republican  ...                                       1
# 37              republican  ...                                       1
# 38              republican  ...                                       2
# 49              republican  ...                                       2
# 51              republican  ...                                       1
# 53              republican  ...                                       2
# 55              republican  ...                                       2
# 56              republican  ...                                       1
# 57              republican  ...                                       1
# 58              republican  ...                                       1
# 59              republican  ...                                       1
# 61              republican  ...                                       2
# 65              republican  ...                                       1
# 66              republican  ...                                       1
# 67              republican  ...                                       2
# 71              republican  ...                                       1
# 73              republican  ...                                       1
# ..                     ...  ...                                     ...
# 356             republican  ...                                       2
# 357             republican  ...                                       2
# 359             republican  ...                                       1
# 363             republican  ...                                       2
# 364             republican  ...                                       1
# 369             republican  ...                                       1
# 374             republican  ...                                       1
# 377             republican  ...                                       1
# 378             republican  ...                                       1
# 379             republican  ...                                       1
# 392             republican  ...                                       1
# 393             republican  ...                                       1
# 399             republican  ...                                       2
# 400             republican  ...                                       1
# 401             republican  ...                                       2
# 402             republican  ...                                       1
# 403             republican  ...                                       2
# 404             republican  ...                                       1
# 405             republican  ...                                       1
# 409             republican  ...                                       2
# 410             republican  ...                                       1
# 412             republican  ...                                       1
# 413             republican  ...                                       1
# 416             republican  ...                                       1
# 420             republican  ...                                       1
# 427             republican  ...                                       1
# 430             republican  ...                                       1
# 432             republican  ...                                       1
# 433             republican  ...                                       1
# 434             republican  ...                                       2
#
# [168 rows x 17 columns]

# %%
new_df.update(democrat)

# %%
new_df
# Out:
#     Democrat or Republican  ...  Export Administration Act South Africa
# 0               republican  ...                                       1
# 1               republican  ...                                     nan
# 2                 democrat  ...                                       2
# 3                 democrat  ...                                       1
# 4                 democrat  ...                                       1
# 5                 democrat  ...                                       1
# 6                 democrat  ...                                       1
# 7               republican  ...                                       1
# 8               republican  ...                                       1
# 9                 democrat  ...                                       1
# 10              republican  ...                                       2
# 11              republican  ...                                     nan
# 12                democrat  ...                                       1
# 13                democrat  ...                                       1
# 14              republican  ...                                     nan
# 15              republican  ...                                     nan
# 16                democrat  ...                                       1
# 17                democrat  ...                                       1
# 18              republican  ...                                       2
# 19                democrat  ...                                       1
# 20                democrat  ...                                       1
# 21                democrat  ...                                       1
# 22                democrat  ...                                       1
# 23                democrat  ...                                       1
# 24                democrat  ...                                       1
# 25                democrat  ...                                       1
# 26                democrat  ...                                       1
# 27                democrat  ...                                       1
# 28              republican  ...                                       1
# 29                democrat  ...                                       1
# ..                     ...  ...                                     ...
# 405             republican  ...                                       1
# 406               democrat  ...                                       1
# 407               democrat  ...                                       2
# 408               democrat  ...                                       1
# 409             republican  ...                                       2
# 410             republican  ...                                       1
# 411               democrat  ...                                       1
# 412             republican  ...                                       1
# 413             republican  ...                                       1
# 414               democrat  ...                                       1
# 415               democrat  ...                                       1
# 416             republican  ...                                       1
# 417               democrat  ...                                       1
# 418               democrat  ...                                       1
# 419               democrat  ...                                       1
# 420             republican  ...                                       1
# 421               democrat  ...                                       1
# 422               democrat  ...                                       1
# 423               democrat  ...                                       1
# 424               democrat  ...                                       1
# 425               democrat  ...                                       1
# 426               democrat  ...                                       1
# 427             republican  ...                                       1
# 428               democrat  ...                                       1
# 429               democrat  ...                                       1
# 430             republican  ...                                       1
# 431               democrat  ...                                       1
# 432             republican  ...                                       1
# 433             republican  ...                                       1
# 434             republican  ...                                       2
#
# [435 rows x 17 columns]

# %%
new_df.update(republican)

# %%
new_df
# Out:
#     Democrat or Republican  ...  Export Administration Act South Africa
# 0               republican  ...                                       1
# 1               republican  ...                                       1
# 2                 democrat  ...                                       2
# 3                 democrat  ...                                       1
# 4                 democrat  ...                                       1
# 5                 democrat  ...                                       1
# 6                 democrat  ...                                       1
# 7               republican  ...                                       1
# 8               republican  ...                                       1
# 9                 democrat  ...                                       1
# 10              republican  ...                                       2
# 11              republican  ...                                       1
# 12                democrat  ...                                       1
# 13                democrat  ...                                       1
# 14              republican  ...                                       1
# 15              republican  ...                                       1
# 16                democrat  ...                                       1
# 17                democrat  ...                                       1
# 18              republican  ...                                       2
# 19                democrat  ...                                       1
# 20                democrat  ...                                       1
# 21                democrat  ...                                       1
# 22                democrat  ...                                       1
# 23                democrat  ...                                       1
# 24                democrat  ...                                       1
# 25                democrat  ...                                       1
# 26                democrat  ...                                       1
# 27                democrat  ...                                       1
# 28              republican  ...                                       1
# 29                democrat  ...                                       1
# ..                     ...  ...                                     ...
# 405             republican  ...                                       1
# 406               democrat  ...                                       1
# 407               democrat  ...                                       2
# 408               democrat  ...                                       1
# 409             republican  ...                                       2
# 410             republican  ...                                       1
# 411               democrat  ...                                       1
# 412             republican  ...                                       1
# 413             republican  ...                                       1
# 414               democrat  ...                                       1
# 415               democrat  ...                                       1
# 416             republican  ...                                       1
# 417               democrat  ...                                       1
# 418               democrat  ...                                       1
# 419               democrat  ...                                       1
# 420             republican  ...                                       1
# 421               democrat  ...                                       1
# 422               democrat  ...                                       1
# 423               democrat  ...                                       1
# 424               democrat  ...                                       1
# 425               democrat  ...                                       1
# 426               democrat  ...                                       1
# 427             republican  ...                                       1
# 428               democrat  ...                                       1
# 429               democrat  ...                                       1
# 430             republican  ...                                       1
# 431               democrat  ...                                       1
# 432             republican  ...                                       1
# 433             republican  ...                                       1
# 434             republican  ...                                       2
#
# [435 rows x 17 columns]

# %%
d_handicap = democrat['Handicapped infants'].mean()
d_handicap
# Out:
# 1.3820224719101124

# %%
r_handicap = republican['Handicapped infants'].mean()
r_handicap
# Out:
# 1.8154761904761905

# %%
d_water = democrat['Water project'].mean()
d_water
# Out:
# 1.445692883895131

# %%
r_water = republican['Water project'].mean()
r_water
# Out:
# 1.4345238095238095

# %%
d_adoption = democrat['Adoption of the budget resolution'].mean()
d_adoption
# Out:
# 1.1086142322097379

# %%
r_adoption = republican['Adoption of the budget resolution'].mean()
r_adoption
# Out:
# 1.869047619047619

# %%
d_nicaragua = democrat['Aid to Nicaraguan contras'].mean()
d_nicaragua
# Out:
# 1.1685393258426966

# %%
r_nicaragua = republican['Aid to Nicaraguan contras'].mean()
r_nicaragua
# Out:
# 1.8571428571428572

# %%
d_missile = democrat['Mx missile'].mean()
d_missile
# Out:
# 1.2247191011235956

# %%
r_missile = republican['Mx missile'].mean()
r_missile
# Out:
# 1.8869047619047619

# %%
from scipy.stats import ttest_ind, ttest_ind_from_stats, ttest_rel

# %%
 ttest_ind(r_missile, d_missile, equal_var=False)
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/core/fromnumeric.py:3367: RuntimeWarning: Degrees of freedom <= 0 for slice
#   **kwargs)
# /usr/local/lib/python3.6/dist-packages/numpy/core/_methods.py:132: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Ttest_indResult(statistic=nan, pvalue=nan)

# %%
ttest_ind(r_nicaragua, d_nicaragua)
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/core/fromnumeric.py:3367: RuntimeWarning: Degrees of freedom <= 0 for slice
#   **kwargs)
# /usr/local/lib/python3.6/dist-packages/numpy/core/_methods.py:132: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Ttest_indResult(statistic=nan, pvalue=nan)

# %%
ttest_ind(d_adoption, r_adoption)
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/core/fromnumeric.py:3367: RuntimeWarning: Degrees of freedom <= 0 for slice
#   **kwargs)
# /usr/local/lib/python3.6/dist-packages/numpy/core/_methods.py:132: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Ttest_indResult(statistic=nan, pvalue=nan)
